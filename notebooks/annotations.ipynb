# %%
import json

file_path = "../data/annotations/instances_val2017.json"

with open(file_path, "r") as f:
    coco = json.load(f)

for cat in coco["categories"]:
    if cat["name"] == "person":
        print(cat)
# Out:
# {'supercategory': 'person', 'id': 1, 'name': 'person'}

# %%
import json

file_path = "../data/annotations/instances_val2017.json"

with open(file_path, "r") as f:
    coco = json.load(f)

print("COCO loaded successfully")
# Out:
# COCO loaded successfully

# %%
img = coco["images"][0]
img_id = img["id"]
print(img)
# Out:
# {'license': 4, 'file_name': '000000397133.jpg', 'coco_url': 'http://images.cocodataset.org/val2017/000000397133.jpg', 'height': 427, 'width': 640, 'date_captured': '2013-11-14 17:02:52', 'flickr_url': 'http://farm7.staticflickr.com/6116/6255196340_da26cf2c9e_z.jpg', 'id': 397133}

# %%
img = coco["images"][10]
img_id = img["id"]
print(img)
# Out:
# {'license': 3, 'file_name': '000000296649.jpg', 'coco_url': 'http://images.cocodataset.org/val2017/000000296649.jpg', 'height': 427, 'width': 640, 'date_captured': '2013-11-15 15:26:19', 'flickr_url': 'http://farm4.staticflickr.com/3577/3491669985_d81e1050c6_z.jpg', 'id': 296649}

# %%
anns = [a for a in coco["annotations"] if a["image_id"] == img_id]
print("Total objects:", len(anns))
# Out:
# Total objects: 26

# %%
person_anns = [a for a in anns if a["category_id"] == 1]
print("Persons in image:", len(person_anns))
# Out:
# Persons in image: 13
